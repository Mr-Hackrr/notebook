# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-Hackrr/notebook/blob/main/notebooks/day4q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"/content/ForbesAmericasTopColleges2019.csv")

# %%
data.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df = data.copy()

# %%
df.loc[:6,'Name']
# Out:
# 0                       Harvard University
# 1                      Stanford University
# 2                          Yale University
# 3    Massachusetts Institute of Technology
# 4                     Princeton University
# 5               University of Pennsylvania
# 6                         Brown University
# Name: Name, dtype: object

# %%
df.loc[:6,['Name','State','City']]
# Out:
#                                     Name State          City
# 0                     Harvard University    MA     Cambridge
# 1                    Stanford University    CA      Stanford
# 2                        Yale University    CT     New Haven
# 3  Massachusetts Institute of Technology    MA     Cambridge
# 4                   Princeton University    NJ     Princeton
# 5             University of Pennsylvania    PA  Philadelphia
# 6                       Brown University    RI    Providence

# %%
df['State'].unique()
# Out:
# array(['MA', 'CA', 'CT', 'NJ', 'PA', 'RI', 'NC', 'NH', 'NY', 'DC', 'IL',
#        'IN', 'MI', 'TX', 'MD', 'ME', 'TN', 'MO', 'VA', 'VT', 'CO', 'MN',
#        'GA', 'WA', 'WI', 'FL', 'OH', 'IA', 'UT', 'OR', 'LA', 'SC', 'DE',
#        'AL', 'AZ', 'OK', 'NE', 'KY', 'KS', 'AR', 'WY', 'NV', 'MS', 'ND',
#        'HI', 'MT', 'SD', 'NM', 'ID', 'WV', 'AK'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 51

# %%
df.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
private_cnt = 0
public_cnt = 0
for i in df['Public/Private']:
  if i == 'Public':
    public_cnt += 1
  elif i == 'Private':
    private_cnt += 1
  else:
    pass

print("Number of public colleges: ",public_cnt)
print("Number of private colleges: ",private_cnt)
# Out:
# Number of public colleges:  250
# Number of private colleges:  400

# %%
state_list = df['State'].unique()
# Out:
# array(['MA', 'CA', 'CT', 'NJ', 'PA', 'RI', 'NC', 'NH', 'NY', 'DC', 'IL',
#        'IN', 'MI', 'TX', 'MD', 'ME', 'TN', 'MO', 'VA', 'VT', 'CO', 'MN',
#        'GA', 'WA', 'WI', 'FL', 'OH', 'IA', 'UT', 'OR', 'LA', 'SC', 'DE',
#        'AL', 'AZ', 'OK', 'NE', 'KY', 'KS', 'AR', 'WY', 'NV', 'MS', 'ND',
#        'HI', 'MT', 'SD', 'NM', 'ID', 'WV', 'AK'], dtype=object)
